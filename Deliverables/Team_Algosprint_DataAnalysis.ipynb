# %% [markdown]
# # EXPLORATORY DATA ANALYSIS (EDA)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=  pd.read_csv('health_infrastructure.csv')

# %%
df.head()
# Out:
#      Country  Year  Hospital_density           gdp  Communicable_disease  \
# 0  Australia  2000             6.648  4.158450e+11                  35.6
# 1  Australia  2001             6.656  3.793580e+11                  53.3
# 2  Australia  2002             6.586  3.955730e+11                  32.2
# 3  Australia  2003             6.521  4.674980e+11                  29.3
# 4  Australia  2004             6.477  6.143260e+11                  46.4
#
#    Hospital_Expenditure  Total_Health_Expenditure  Injury Count  \
# 0                 2.987                     7.594        138.30
# 1                 3.024                     7.678        141.76
# 2                 3.123                     7.876        142.60
# 3                 3.157                     7.881        143.47
# 4                 3.250                     8.087        144.10
#
#    life_expectancy  Mortality  Population
# 0             79.2      676.8  19028802.0
# 1             79.6      667.5  19274701.0
# ...

# %%
# standardizing the country column

df['Country'] = df['Country'].str.upper()

# %%
df.head()
# Out:
#      Country  Year  Hospital_density           gdp  Communicable_disease  \
# 0  AUSTRALIA  2000             6.648  4.158450e+11                  35.6
# 1  AUSTRALIA  2001             6.656  3.793580e+11                  53.3
# 2  AUSTRALIA  2002             6.586  3.955730e+11                  32.2
# 3  AUSTRALIA  2003             6.521  4.674980e+11                  29.3
# 4  AUSTRALIA  2004             6.477  6.143260e+11                  46.4
#
#    Hospital_Expenditure  Total_Health_Expenditure  Injury Count  \
# 0                 2.987                     7.594        138.30
# 1                 3.024                     7.678        141.76
# 2                 3.123                     7.876        142.60
# 3                 3.157                     7.881        143.47
# 4                 3.250                     8.087        144.10
#
#    life_expectancy  Mortality  Population
# 0             79.2      676.8  19028802.0
# 1             79.6      667.5  19274701.0
# ...

# %% [markdown]
# # Visualization of the relationship between the Hosital Density and each of the variables

# %% [markdown]
# ## GDP vs. Hospital Density

# %%
plt.figure(figsize=(8, 6))

plt.scatter(df['gdp'], df['Hospital_density'], color="green")

plt.xlabel('GDP')
plt.ylabel('Hospital Density')

plt.title('Hospital Density Versus GDP')

plt.grid(True)

plt.show()

# %% [markdown]
# `Observation`
#
# * A general trend observed is that countries with lower GDP tend to have lower hospital densities. This correlation suggests that economic constraints can impact a country's ability to invest in healthcare infrastructure, leading to a lower density of hospitals.
#
# * there are exceptions to this correlation, where countries with quite low GDP levels exhibit exceptionally high hospital densities. These exceptions may be influenced by unique factors such as government initiatives, international aid, or specific healthcare policies that prioritize healthcare infrastructure development.

# %% [markdown]
# ## <span style="color:orange;">Hospital_density vs. Communicable Diseases</span>

# %%
plt.figure(figsize=(8, 6))
plt.scatter(df['Communicable_disease'], df['Hospital_density'], color="red")
plt.xlabel('Communicable_disease')
plt.ylabel('Hospital Density')
plt.title('Hospital Density Versus Communicable_disease ')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Hospital_density vs. Hospital_Expenditure

# %%
plt.figure(figsize=(8, 6))
plt.scatter(df['Hospital_Expenditure'], df['Hospital_density'])
plt.xlabel('Hospital_Expenditure')
plt.ylabel('Hospital Density')
plt.title('Hospital Density versus Hospital_Expenditure')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Hospital_density vs. Injury Count

# %%
plt.figure(figsize=(8, 6))
plt.scatter(df['Injury Count'], df['Hospital_density'], color="red")
plt.xlabel('Injury Count')
plt.ylabel('Hospital Density')
plt.title('Hospital Density versus Injury Count')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Hospital_density vs. life_expectancy

# %%
plt.figure(figsize=(8, 6))
plt.scatter(df['life_expectancy'], df['Hospital_density'])
plt.xlabel('life_expectancy')
plt.ylabel('Hospital Density')
plt.title('Hospital Density versus life_expectancy')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Hospital_density vs. Mortality

# %%
plt.figure(figsize=(8, 6))
plt.scatter(df['Mortality'], df['Hospital_density'], color="red")
plt.xlabel('Mortality')
plt.ylabel('Hospital Density')
plt.title('Hospital Density versus Mortality')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Hospital_density vs. Population

# %%
plt.figure(figsize=(8, 6))
plt.scatter(df['Population'], df['Hospital_density'])
plt.xlabel('Population')
plt.ylabel('Hospital Density')
plt.title('Hospital Density versus Population')
plt.grid(True)
plt.show()

# %% [markdown]
# ## GDP over the Years

# %%
# Create a figure with a specific size
plt.figure(figsize=(8, 5))

# Create a line plot using Seaborn, with 'Year' on the x-axis and 'gdp' on the y-axis
sns.lineplot(x='Year', y='gdp', data=df, marker='o')

# Set the title of the plot
plt.title('GDP over the Years')

# Display a grid on the plot for better readability
plt.grid(True)

# Show the plot
plt.show()

# %% [markdown]
# `Observations`
#
# - From the above time series, we can see that the gdp increases over time. There was a dip around 2019 to 2020 probably due to the covid 19 pandemic
# - but beyond 2020 its the highest its ever been signaling a recovery in the worldwide economy

# %% [markdown]
# ## Total Health Expenditure over the Years

# %%
# Create a figure with a specific size
plt.figure(figsize=(8, 5))

# Create a line plot using Seaborn, with 'Year' on the x-axis and 'Total_Health_Expenditure' on the y-axis
sns.lineplot(x='Year', y='Total_Health_Expenditure', data=df, marker='o')

# Set the title of the plot
plt.title('Total Health Expenditure over the Years')

# Display a grid on the plot for better readability
plt.grid(True)

# Show the plot
plt.show()

# %% [markdown]
# `Observation`
#
# - The data reveals a notable trend of increasing total health expenditure over the years. This rise is likely influenced by the general increase in GDP over the same period, as shown in the previous time series analysis. As a country's GDP grows, there is typically a corresponding increase in the overall budget allocated to healthcare.
#
# - One of the most significant observations in the data is the sharp rise in healthcare expenditure between 2020 and 2021. This substantial increase can largely be attributed to the COVID-19 pandemic. The pandemic strained healthcare systems worldwide, leading to increased funding requirements for medical supplies, treatment, testing, and vaccination campaigns.

# %% [markdown]
# ## Life_expectancy over the Years

# %%
# Create a figure with a specific size
plt.figure(figsize=(8, 5))

# Create a line plot using Seaborn, with 'Year' on the x-axis and 'life_expectancy' on the y-axis
sns.lineplot(x='Year', y='life_expectancy', data=df, marker='o')

# Set the title of the plot
plt.title('Life Expectancy over the Years')

# Display a grid on the plot for better readability
plt.grid(True)

# Show the plot
plt.show()

# %% [markdown]
# `Observation`
#
# - The data indicates a substantial increase in life expectancy over the years. This positive trend suggests improvements in healthcare, healthcare access, and overall living conditions, contributing to longer and healthier lives for the population.
#
# - A notable deviation from the upward trend occurred around 2019, where there was a dip in life expectancy. This dip was followed by a continued decrease in subsequent years. Such a trend is cause for concern as it signifies a departure from the previously improving life expectancy rates.
#
# - The dip in life expectancy in 2019 and the subsequent decline are highly likely attributable to the COVID-19 pandemic. The pandemic had a significant impact on public health, leading to increased mortality rates. The disease, coupled with disruptions in healthcare systems, medical resource allocation, and economic hardships, contributed to a reduction in life expectancy.

# %% [markdown]
# ## Hospital_density

# %%
# Create a figure with a specific size
plt.figure(figsize=(8, 5))

# Create a histogram plot using Seaborn with data from the 'Hospital_density' column
sns.histplot(df['Hospital_density'], label='Hospital Density')

# Display a grid on the plot for better readability
plt.grid(True)

# Show the plot
plt.show()

# %% [markdown]
# `Observation`
#
# - The data reveals a central range of hospital density that is most common among the majority of countries. This range typically falls between 3 and 5 hospitals per unit of measurement (such as population or area). This suggests that many countries maintain a relatively moderate number of hospitals to cater to their healthcare needs.
#
# - Beyond this central range, there is a gradual decrease in hospital density as we move to countries with both higher and lower densities. This indicates that while moderate hospital density is common, extreme variations in either direction (very high or very low density) become less common.
#
# - The trend of decreasing hospital density as we move away from the central range highlights the variability in healthcare infrastructure among different countries. Some countries may prioritize quality over quantity, investing in advanced healthcare facilities, while others may focus on efficient resource allocation.
#
# - Some countries exhibit an unusually high concentration of hospitals, exceeding the expected range. These countries can be considered outliers in terms of hospital density.

# %% [markdown]
# ## Hospital Expenditure

# %%
# Create a figure with a specific size
plt.figure(figsize=(8, 5))

# Create a histogram plot using Seaborn with data from the 'Hospital_Expenditure' column
sns.histplot(df['Hospital_Expenditure'], label='Hospital Expenditure')

# Display a grid on the plot for better readability
plt.grid(True)

# Show the plot
plt.show()

# %% [markdown]
# `Observation`
#
# - In many countries, the allocation of financial resources to the medical and health sector is below the average expenditure level. This suggests that healthcare may not receive a significant share of the national budget. There could be various reasons for this, including competing budgetary priorities, limited financial resources, or variations in the perceived importance of healthcare compared to other sectors.
#
# - A significant portion of nations doesn't heavily invest in their health expenditure budgets. This can have implications for the quality and accessibility of healthcare services. Lower healthcare investment might lead to challenges in providing adequate healthcare infrastructure, training healthcare professionals, and ensuring the availability of essential medical supplies and equipment.
#
# - However, there are exceptions to this trend. A few countries stand out as outliers by heavily investing in their health expenditure budgets. These nations prioritize healthcare and allocate a substantial portion of their budget to ensure the well-being of their population. High healthcare expenditure can lead to better healthcare infrastructure, increased access to medical services, and potentially improved health outcomes for their citizens.

# %% [markdown]
# ## Correlation Heatmap

# %%
# Calculate the correlation matrix for selected columns
#correlation_matrix = df[['Hospital_density', 'gdp', 'life_expectancy', 'Mortality', 'Hospital_Expenditure', 'Total_Health_Expenditure']].corr()
correlation_matrix=df.drop(["Year"], axis=1).corr()
# Create a heatmap to visualize the correlation matrix, with annotations
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')

# Set the title of the plot
plt.title('Correlation Heatmap')

# Show the heatmap
plt.show()
# Out:
# C:\Users\Anih Nathan\AppData\Local\Temp\ipykernel_2180\1098079095.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix=df.drop(["Year"], axis=1).corr()

# %% [markdown]
# `Observations`
#
# - Hospital Density shows a weak negative correlation with GDP (-0.021798) and Life Expectancy (-0.167741). This suggests that as hospital density increases, GDP and life expectancy tend to decrease slightly. This could imply that countries with higher GDPs may have lower hospital densities, possibly due to more advanced healthcare systems or fewer hospitals per capita.
#
# - Hospital Density has a negative correlation with Mortality (-0.202806), indicating that in countries with higher hospital density, mortality rates tend to be lower. This suggests that having more hospitals may contribute to better health outcomes.
#
# - Life Expectancy and Mortality show a strong negative correlation (-0.375352), which is expected. As life expectancy increases, mortality rates tend to decrease. This reflects the general principle that longer life expectancy is associated with better health outcomes.
#
# - GDP also has a positive correlation with Hospital Expenditure (0.362093) and Total Health Expenditure (0.645611), indicating that wealthier countries tend to allocate more resources to healthcare.
#
# - Hospital density and Total Health Expenditure are positively correlated with a moderate strength (0.500842 and 0.592631, respectively). This suggests that countries with higher hospital expenditure also tend to have higher total health expenditure, indicating a significant investment in healthcare infrastructure.

# %% [markdown]
# ## Hospital_density for different countries

# %%
sorted_df = df.sort_values(by=["Hospital_density"])
# Define a list of colors for the barplot
colors = ['cyan', 'red', 'green', 'orange', 'blue', 'limegreen', 'darkgreen', 'royalblue', 'navy']

# Create a figure with a specific size
plt.figure(figsize=(14, 5))

# Create a barplot using Seaborn, with 'Country' on the x-axis and 'Hospital_density' on the y-axis, using the defined color palette
sns.barplot(x='Country', y='Hospital_density', data=sorted_df, palette=colors)

# Set the title of the plot
plt.title('View Hospital Density for Different Countries')

# Rotate the x-axis labels for better readability
plt.xticks(rotation=90)

# Show the barplot
plt.show()

# %% [markdown]
# `Observation`
#
# - In a densely populated country like Colombia, there are more people for each hospital to serve. This means that even with a moderate number of hospitals, the population's needs can be met, leading to higher hospital density. In contrast, in less densely populated countries, the same number of hospitals would serve fewer people, resulting in lower hospital density.

# %% [markdown]
# ## <span style="color:orange;">gdp vs Mortality vs Hospital Density</span>

# %%
# Create a figure and 3D axis
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

# Define color mapping for Mortality values
colors = df['Mortality']
colormap = plt.get_cmap('viridis')
normalize = plt.Normalize(np.min(colors), np.max(colors))

# Create a scatter plot with color mapping
sc = ax.scatter(df['gdp'], df['Hospital_density'], df['Mortality'], c=colors, cmap=colormap, marker='o', s=60, alpha=0.8)

# Customize the color bar
cbar = fig.colorbar(sc, ax=ax, pad=0.1)
cbar.set_label('Mortality')
cbar.ax.yaxis.labelpad = 12

# Add grid lines
ax.grid(True, linestyle='--', alpha=0.7)

# Label the axes and add a title
ax.set_xlabel('GDP')
ax.set_ylabel('Hospital Density')
ax.set_zlabel('Mortality')
ax.set_title('3D Scatter Plot')

plt.show()

# %% [markdown]
# `Observations`
#
# - Many countries with below-average hospital density also tend to have low GDP. This connection suggests that countries with limited hospital infrastructure may face challenges in allocating sufficient financial resources to healthcare. Lower GDP can lead to constraints in developing and maintaining healthcare facilities.
#
# - There appears to be an inverse relationship between hospital density and mortality rate. As hospital density increases, the mortality rate tends to decrease. This observation aligns with the general understanding that having more hospitals and healthcare facilities often leads to better access to medical care and, consequently, lower mortality rates.
#
# - Countries with moderate GDP levels that also maintain a medium level of hospital density tend to exhibit very low mortality rates. This observation suggests that a balance between healthcare infrastructure (as indicated by hospital density) and financial resources (as indicated by GDP) can contribute to improved healthcare outcomes.
#
# - Many countries  exhibit low hospital density, low GDP, and a moderate mortality rate. This combination suggests that economic constraints may lead to limited healthcare infrastructure and, in turn, moderately elevated mortality rates.
#
# - On the other end of the spectrum, we find countries with high hospital density, high GDP, and low mortality rates. These countries have invested significantly in healthcare infrastructure and have the financial means to support advanced medical services, resulting in lower mortality rates.

# %% [markdown]
# ## <span style="color:orange;">GDP, Hospital Density, and Health Expenditure per Capita</span>

# %%
# Calculate 'Health_Expenditure_Per_Capita' by dividing 'Total_Health_Expenditure' by 'Population'
df['Health_Expenditure_Per_Capita'] = df['Total_Health_Expenditure'] / df['Population']

# Create a figure with a specific size
plt.figure(figsize=(6, 5))

# Create a scatter plot with 'GDP' on the x-axis, 'Hospital_density' on the y-axis, and color-coded by 'Health_Expenditure_Per_Capita'
sns.scatterplot(x='gdp', y='Hospital_density', hue='Health_Expenditure_Per_Capita', data=df, palette='viridis')

# Set labels for the x and y axes
plt.xlabel('GDP')
plt.ylabel('Hospital Density')

# Set the title of the plot
plt.title('GDP, Hospital Density, and Health Expenditure per Capita')

# Show the scatter plot
plt.show()

# %% [markdown]
# `Observations`
#
# - It's evident that countries with a high health expenditure per capita often have below-average hospital densities. This pattern may seem counterintuitive at first. However, it could be due to factors such as high healthcare costs, investments in specialized healthcare services, or a focus on quality over quantity.
#
# - High health expenditure per capita suggests that the country is allocating a significant portion of its healthcare budget to each individual's health needs, potentially leading to lower hospital densities as resources are concentrated on advanced medical services and technologies not necessarily hospital densities
#
# - Notably, there are outliers in this dataset: countries with high hospital densities, low GDP, and high health expenditure per capita. These outliers represent unique cases where certain countries prioritize healthcare investment despite economic limitations.
#
# - These outliers may have specific reasons for their high health expenditure per capita, such as addressing specific healthcare challenges or providing specialized medical services. Their high hospital density, despite low GDP, could be a result of a strong emphasis on accessible healthcare infrastructure, even with limited economic resources

# %% [markdown]
# ## <span style="color:orange;">Top 15 Countries with Highest Mean Communicable Disease Rates and Mean Hospital Density</span>

# %%
# Select and sort the top communicable disease rates along with hospital density for each country
top_communicable_disease_rates = df[['Country', 'Communicable_disease', 'Hospital_density']].sort_values(by='Communicable_disease', ascending=False)

# Group the data by 'Country' and calculate the mean of 'Communicable_disease' and 'Hospital_density'
grouped_data = top_communicable_disease_rates.groupby('Country').agg({'Communicable_disease': 'mean', 'Hospital_density': 'mean'}).sort_values(by='Communicable_disease', ascending=False).reset_index().head(15)

# Create a figure with a specific size
plt.figure(figsize=(10, 6))

# Create horizontal bar charts for 'Mean Communicable Disease Rate' and 'Mean Hospital Density' for the top 15 countries
plt.barh(grouped_data['Country'], grouped_data['Communicable_disease'], color='skyblue', label='Mean Communicable Disease Rate')
plt.barh(grouped_data['Country'], grouped_data['Hospital_density'], color='lightcoral', label='Mean Hospital Density', left=grouped_data['Communicable_disease'])

# Set labels for the x and y axes
plt.xlabel('Mean Rates')
plt.ylabel('Country')

# Set the title of the plot
plt.title('Top 15 Countries with Highest Mean Communicable Disease Rates and Mean Hospital Density')

# Add a legend to differentiate the two bars
plt.legend()

# Invert the y-axis to show the highest rates at the top
plt.gca().invert_yaxis()

# Adjust the layout for better display
plt.tight_layout()

# Show the bar chart
plt.show()

# %% [markdown]
# `Observation`
#
# - There is a significant variation in communicable disease rates among these countries. For instance, Australia and Estonia have relatively high rates, while Croatia and Greece have lower rates. This suggests differences in public health measures, healthcare infrastructure, or environmental factors that influence the prevalence of communicable diseases.
#
# - Hospital density also exhibits considerable variation among the countries. Colombia stands out with the highest hospital density, indicating that it has a higher concentration of hospitals relative to its population. On the other hand, Costa Rica has the lowest hospital density among these countries. The differences in hospital density can reflect disparities in healthcare access and infrastructure.
#
# - It's not immediately evident that countries with higher communicable disease rates have correspondingly higher hospital densities. This suggests that factors other than the prevalence of communicable diseases, such as healthcare policies, investment in healthcare infrastructure, and public health initiatives, may be influencing the number of hospitals.
#
# - The economic situation of a country might play a role in hospital density. For instance, Colombia, which has the highest hospital density, may have invested substantially in healthcare infrastructure to serve its large population, despite potential economic constraints. Conversely, some European countries like Austria and Belgium, with lower hospital densities, may prioritize quality healthcare over quantity.

# %% [markdown]
# ## <span style="color:orange;">Hospital_Expenditure vs Hospital_density</span>

# %%
# Group the data by 'Year' and calculate the mean values for several columns
grouped_data2 = df.groupby('Year').agg({
    'Mortality': 'mean',
    'Hospital_density': 'mean',
    'Population': 'mean',
    'Hospital_Expenditure': 'mean'
}).reset_index()

# Create a line plot for 'Hospital_density' over the years
plt.plot(grouped_data2['Year'], grouped_data2['Hospital_density'], label='Hospital_density', marker='o')

# Create a line plot for 'Hospital_Expenditure' over the years
plt.plot(grouped_data2['Year'], grouped_data2['Hospital_Expenditure'], label='Hospital_Expenditure', marker='s')

# Add a legend to differentiate the two lines
plt.legend()

# %% [markdown]
# `Observation`
#
# - Despite the decreasing trend in hospital density over the years, hospital expenditure has consistently risen. This pattern suggests that while the number of hospitals available may be decreasing, there is an increased allocation of financial resources to support healthcare services.
#
# - The decrease in hospital density might indicate a strategic consolidation of healthcare facilities, focusing on efficiency and quality rather than quantity. The increase in hospital expenditure may indicate investments in modernizing existing healthcare infrastructure, improving healthcare services, or incorporating advanced medical technologies.
#
# - These trends might reflect a healthcare strategy that aims to strike a balance between the number of hospitals and the quality of healthcare provided. It's possible that the healthcare system is evolving to ensure that resources are used effectively and that the population has access to advanced and efficient healthcare services.

# %% [markdown]
# ## <span style="color:orange;">Hospital_density per region</span>

# %%
from geopandas.tools import geocode
from geopy.geocoders import Nominatim
import folium

# %%
grouped_data5 = df.groupby('Country')[['Hospital_density', 'Mortality']].mean().reset_index()

# %%
# Create a Nominatim geocoder instance with a custom user agent
nom = Nominatim(user_agent="GetLoc")

# Geocode each location in the 'País' column and assign the result to the 'Geometry' column
grouped_data5['Geometry'] = grouped_data5['Country'].apply(lambda x: nom.geocode(x) if x else None)

# Extract latitude from the 'Geometry' column and assign it to the 'Latitude' column
grouped_data5['Latitude'] = grouped_data5['Geometry'].apply(lambda loc: loc.latitude if loc else None)

# Extract longitude from the 'Geometry' column and assign it to the 'Longitude' column
grouped_data5['Longitude'] = grouped_data5['Geometry'].apply(lambda loc: loc.longitude if loc else None)

# %%
# Create a folium map centered at the specified coordinates with a specific zoom level
m3 = folium.Map(location=[39.326234, -4.838065], tiles='openstreetmap', zoom_start=3)

# Define a function to determine the color based on a value
def color_producer(val):
    if val <= 5:
        return 'red'
    else:
        return 'green'

# Iterate through the data in 'grouped_data5' and add circles to the map
for i in range(0, len(grouped_data5)):
    folium.Circle(
        location=[grouped_data5.iloc[i]['Latitude'], grouped_data5.iloc[i]['Longitude']],
        radius=30000 * grouped_data5.iloc[i]['Hospital_density'],
        color=color_producer(grouped_data5.iloc[i]['Hospital_density'])
    ).add_to(m3)

# Save the map as an HTML file
m3.save('map4.html')

# Display the map
m3
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# `Observations`
#
# - High-income countries like Australia, Japan, and South Korea tend to have higher hospital densities, likely reflecting a greater focus on healthcare infrastructure development.
#
# - Some European countries have moderate hospital densities, indicating a balance between healthcare access and resource allocation.
#
# - Latin American countries exhibit varying hospital densities, with Colombia having the highest among the listed countries.
#
# - orth American countries, Canada and the United States, have relatively lower hospital densities compared to some other high-income nations.
#
# - The specific healthcare policies, healthcare challenges, and population sizes within each country can significantly influence their respective hospital density.

# %% [markdown]
# ## <span style="color:orange;">Hospital_density vs Mortality per region</span>

# %%
# Create a Folium map
m = folium.Map(location=[0, 0], zoom_start=2)

# Assuming you have a DataFrame named grouped_data5 with 'Latitude', 'Longitude', 'Hospital_density', and 'Mortality' columns
for i in range(0, len(grouped_data5)):
    hospital_density = grouped_data5.iloc[i]['Hospital_density']
    mortality = grouped_data5.iloc[i]['Mortality']
    
    # Define a custom color function for 'Hospital_density'
    def hospital_density_color_producer(hd):
        if hd <= 5:
            return 'red'
        else:
            return 'green'
    
    # Define a custom color function for 'Mortality'
    def mortality_color_producer(mort):
        if mort <= 600:
            return 'blue'
        else:
            return 'purple'
    
    # Use different markers for 'Hospital_density' and 'Mortality'
    folium.Circle(
        location=[grouped_data5.iloc[i]['Latitude'], grouped_data5.iloc[i]['Longitude']],
        radius=30000 * hospital_density,
        color=hospital_density_color_producer(hospital_density),
        fill=True,
        fill_color='transparent',
        fill_opacity=0.7,
    ).add_to(m)
    
    folium.Circle(
        location=[grouped_data5.iloc[i]['Latitude'], grouped_data5.iloc[i]['Longitude']],
        radius=200 * mortality,
        color=mortality_color_producer(mortality),
        fill=True,
        fill_color='transparent',
        fill_opacity=0.7,
    ).add_to(m)

# Save the map to an HTML file or display it
m.save('map.html')

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# `Observations`
#
# - European countries tend to have moderate to low hospital densities, suggesting an emphasis on efficient resource allocation and quality healthcare services.
#
# - North American countries exhibit relatively lower hospital densities and varying mortality rates, indicating potential healthcare access disparities and variations in healthcare quality.
#
# - Latin American countries show differences in hospital density and mortality rates, with Colombia having a notably high hospital density and lower mortality rates, potentially indicating effective healthcare resource allocation.
#
# - Asia-Pacific countries, including Australia, Japan, and South Korea, have relatively high hospital densities, reflecting well-established healthcare infrastructures.
#
# - Mortality rates vary among countries, and they are influenced by multiple factors, including healthcare quality, public health measures, and demographic characteristics.
#
# - Each country's healthcare system is tailored to address its unique challenges and healthcare needs, resulting in a diverse range of hospital density and mortality rate combinations.
